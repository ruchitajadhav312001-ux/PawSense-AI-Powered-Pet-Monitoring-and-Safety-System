# %%
from google.colab import drive
drive.mount("/content/drive", force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/MyDrive/Pawsense/data/cat/CAT SKIN DISEASE"
# Out:
# Flea_Allergy  Health  Ringworm	Scabies

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.models import Model
import numpy as np

DATASET_PATH = "/content/drive/MyDrive/Pawsense/data/cat/CAT SKIN DISEASE"

IMG_SIZE = (224, 224)
BATCH_SIZE = 32
EPOCHS = 10

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_gen = datagen.flow_from_directory(
    DATASET_PATH,
    target_size=(224, 224),
    batch_size=32,
    class_mode="categorical",
    subset="training"
)

val_gen = datagen.flow_from_directory(
    DATASET_PATH,
    target_size=(224, 224),
    batch_size=32,
    class_mode="categorical",
    subset="validation"
)
# Out:
# Found 800 images belonging to 4 classes.
# Found 199 images belonging to 4 classes.

# %%
import numpy as np

np.save(
    "/content/drive/MyDrive/Pawsense/model/cat_class_indices.npy",
    train_gen.class_indices
)

print("✅ cat_class_indices.npy saved")
print(train_gen.class_indices)
# Out:
# ✅ cat_class_indices.npy saved
# {'Flea_Allergy': 0, 'Health': 1, 'Ringworm': 2, 'Scabies': 3}

# %%
import tensorflow as tf
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Dropout
from tensorflow.keras.models import Model

# %%
base_model = MobileNetV2(
    weights="imagenet",
    include_top=False,
    input_shape=(224, 224, 3)
)

base_model.trainable = False  # important
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Dense(256, activation="relu")(x)
x = Dropout(0.4)(x)
output = Dense(train_gen.num_classes, activation="softmax")(x)

model = Model(inputs=base_model.input, outputs=output)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)

# %%
history = model.fit(
    train_gen,
    validation_data=val_gen,
    epochs=12
)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/12
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 419s 16s/step - accuracy: 0.3660 - loss: 1.4721 - val_accuracy: 0.6181 - val_loss: 0.9395
# Epoch 2/12
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 248ms/step - accuracy: 0.6456 - loss: 0.8943 - val_accuracy: 0.6884 - val_loss: 0.8058
# Epoch 3/12
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 265ms/step - accuracy: 0.7502 - loss: 0.6241 - val_accuracy: 0.6784 - val_loss: 0.7874
# Epoch 4/12
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 246ms/step - accuracy: 0.8187 - loss: 0.4913 - val_accuracy: 0.7035 - val_loss: 0.7402
# Epoch 5/12
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 266ms/step - accuracy: 0.8524 - loss: 0.4295 - val_accuracy: 0.7236 - val_loss: 0.7122
# Epoch 6/12
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 245ms/step - accuracy: 0.8753 - loss: 0.3702 - val_accuracy: 0.6985 - val_loss: 0.7154
# Epoch 7/12
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 268ms/step - accuracy: 0.8818 - loss: 0.3251 - val_accuracy: 0.7186 - val_loss: 0.7021
# Epoch 8/12
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 243ms/step - accuracy: 0.8994 - loss: 0.2902 - val_accuracy: 0.7236 - val_loss: 0.7138
# Epoch 9/12
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 274ms/step - accuracy: 0.9222 - loss: 0.2674 - val_accuracy: 0.7437 - val_loss: 0.6844
# Epoch 10/12
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 243ms/step - accuracy: 0.9307 - loss: 0.2475 - val_accuracy: 0.7186 - val_loss: 0.7241
# Epoch 11/12
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 279ms/step - accuracy: 0.9337 - loss: 0.2094 - val_accuracy: 0.7286 - val_loss: 0.6835
# Epoch 12/12
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 241ms/step - accuracy: 0.9461 - loss: 0.2066 - val_accuracy: 0.7337 - val_loss: 0.6876

# %%
model.save("/content/drive/MyDrive/Pawsense/model/cat_skin_model_finetuned.keras")
print("✅ Cat skin model saved successfully")
# Out:
# ✅ Cat skin model saved successfully

# %%
# !ls "/content/drive/MyDrive/Pawsense/data/cat/CAT SKIN DISEASE/Ringworm"
# Out:
#  1000010551_x16.jpg
#  1000010607_x4.jpg
#  1000010683_x4.jpg
#  1000010715_x16.jpg
#  1000010751_x16.jpg
#  1000010765_x4.jpg
#  135195862_10222884899858522_306512586281914012_n_jpg.rf.5732898b2448242b3667ffdcd8ceb1f7.jpg
#  135195862_10222884899858522_306512586281914012_n_jpg.rf.7b06be4feae2aa4055353b320501e72f.jpg
#  135195862_10222884899858522_306512586281914012_n_jpg.rf.cc1cebfaa035dc7858b4308b2c029735.jpg
#  136166517_10222884899618516_2057480707672426777_n_jpg.rf.5248d0be9ef2a7c54c671231ab144742.jpg
#  141309628_3721209851319478_6017019068231788383_n.jpg
#  141309628_3721209851319478_6017019068231788383_n_jpg.rf.a45707d7e04dc6185ba0d1f8532566cc.jpg
#  141725846_3721210257986104_5054501378569814826_n_jpg.rf.01458697ca44bce018610df7a0879023.jpg
#  Screenshot-2024-10-14-180548_png.rf.cd3af31c48624838bb7d5d3b8049e9ab.jpg
#  Screenshot-2024-10-14-180548_png.rf.df386ba8e584b27d15ae5094cad1da74.jpg
#  Screenshot-2024-10-14-180656_png.rf.99629fdf7494b4bf29eb30d13573f2fd.jpg
#  Screenshot-2024-10-14-180656_png.rf.d1f6be7f8e2f1ab194f24832da5973ab.jpg
#  Screenshot-2024-10-14-182237_png.rf.970d845b7230ff0e2f62a07712f79bcc.jpg
#  Screenshot-2024-10-14-182237_png.rf.ac0f290059cca45b9e1444001703f753.jpg
# 'Screenshot 2024-11-16 181028.png'
# 'Screenshot 2024-11-16 181047.png'
# 'Screenshot 2024-11-16 181130.png'
# 'Screenshot 2024-11-16 181434.png'
# 'Screenshot 2024-11-16 181513.png'
# 'Screenshot 2024-11-16 181725.png'
# 'Screenshot 2024-11-16 181809.png'
# 'Screenshot 2024-11-16 181936.png'
# 'Screenshot 2024-11-16 182105.png'
# 'Screenshot 2024-11-16 182320.png'
# 'Screenshot 2024-11-16 182449.png'
# 'Screenshot 2024-11-16 182620.png'
# 'Screenshot 2024-11-16 182913.png'
# 'Screenshot 2024-11-16 182941.png'
# 'Screenshot 2024-11-16 183007.png'
# 'Screenshot 2024-11-16 183050.png'
# 'Screenshot 2024-11-16 183222.png'
# 'Screenshot 2024-11-16 183256.png'
# 'Screenshot 2024-11-16 183315.png'
# 'Screenshot 2024-11-16 183716.png'
# 'Screenshot 2024-11-16 184110.png'
# 'Screenshot 2024-11-16 184314.png'
# 'Screenshot 2024-11-16 184449.png'
#  Thank-you-all-for-your-support_00004.jpg
#  waj14_jpeg.jpg
#  waj1_jpeg.jpg
#  waj5_jpeg.jpg
#  waj6_jpeg.jpg
#  waj9_jpeg.jpg
#  was4_jpeg.jpg

# %%
test_img = "/content/drive/MyDrive/Pawsense/data/cat/CAT SKIN DISEASE/Ringworm/ringworm10.jpg"

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

img = image.load_img(test_img, target_size=(224,224))
img_arr = image.img_to_array(img) / 255.0
img_arr = np.expand_dims(img_arr, axis=0)

pred = model.predict(img_arr)
print("Predicted class index:", np.argmax(pred))
print("Confidence:", np.max(pred) * 100)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 12s 12s/step
# Predicted class index: 2
# Confidence: 77.2176

# %%
cat_idx_to_class = {v: k for k, v in train_gen.class_indices.items()}
cat_idx_to_class
# Out:
# {0: 'Flea_Allergy', 1: 'Health', 2: 'Ringworm', 3: 'Scabies'}

# %%
model.save("/content/drive/MyDrive/Pawsense/model/cat_skin_model_finetuned.keras")
print("✅ Cat model saved")
# Out:
# ✅ Cat model saved

# %%
import numpy as np

np.save(
    "/content/drive/MyDrive/Pawsense/model/cat_class_indices.npy",
    train_gen.class_indices
)
print("✅ cat_class_indices.npy saved")
# Out:
# ✅ cat_class_indices.npy saved

# %%
import os
import io
import numpy as np
import tensorflow as tf
from PIL import Image

BASE_DIR = "/content/drive/MyDrive/Pawsense"

# %%
CAT_SKIN_MODEL_PATH = os.path.join(
    BASE_DIR,
    "model",
    "cat_skin_model_finetuned.keras",
)

CAT_CLASS_IDX_PATH = os.path.join(
    BASE_DIR,
    "model",
    "cat_class_indices.npy",
)

# %%
print("🔄 Loading cat skin model...")

cat_skin_model = tf.keras.models.load_model(CAT_SKIN_MODEL_PATH)
cat_class_indices = np.load(CAT_CLASS_IDX_PATH, allow_pickle=True).item()
cat_idx_to_class = {v: k for k, v in cat_class_indices.items()}

print("✅ Cat skin model loaded")
print("✅ Cat skin classes:", cat_idx_to_class)
# Out:
# 🔄 Loading cat skin model...
# ✅ Cat skin model loaded
# ✅ Cat skin classes: {0: 'Flea_Allergy', 1: 'Health', 2: 'Ringworm', 3: 'Scabies'}

# %%
CAT_SOS_DISEASES = {"Ringworm", "Scabies"}
CAT_SOS_THRESHOLD = 80.0

# %%
from fastapi import FastAPI

app = FastAPI(title="PawSense Backend")

# %%
# !pip install twilio

# imports
import os
import io
import numpy as np
import tensorflow as tf
from PIL import Image

from fastapi import FastAPI, UploadFile, File
from fastapi.middleware.cors import CORSMiddleware
from fastapi.responses import JSONResponse

from twilio.rest import Client
# Out:
# Collecting twilio
#   Downloading twilio-9.9.0-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from twilio) (2.32.4)
# Requirement already satisfied: PyJWT<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from twilio) (2.10.1)
# Requirement already satisfied: aiohttp>=3.8.4 in /usr/local/lib/python3.12/dist-packages (from twilio) (3.13.2)
# Collecting aiohttp-retry>=2.8.3 (from twilio)
#   Downloading aiohttp_retry-2.9.1-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.4->twilio) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.4->twilio) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.4->twilio) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.4->twilio) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.4->twilio) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.4->twilio) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp>=3.8.4->twilio) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->twilio) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->twilio) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->twilio) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->twilio) (2025.11.12)
# Requirement already satisfied: typing-extensions>=4.2 in /usr/local/lib/python3.12/dist-packages (from aiosignal>=1.4.0->aiohttp>=3.8.4->twilio) (4.15.0)
# Downloading twilio-9.9.0-py2.py3-none-any.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 33.7 MB/s eta 0:00:00
# Downloading aiohttp_retry-2.9.1-py3-none-any.whl (10.0 kB)
# Installing collected packages: aiohttp-retry, twilio
# Successfully installed aiohttp-retry-2.9.1 twilio-9.9.0

# %%
# app creation
app = FastAPI(title="PawSense Backend")

# %%
# middleware
app.add_middleware(
    CORSMiddleware,
    allow_origins=["*"],
    allow_methods=["*"],
    allow_headers=["*"],
)

# %%
@app.post("/cat-skin")
async def predict_cat_skin(image: UploadFile = File(...)):
    try:
        contents = await image.read()
        img = Image.open(io.BytesIO(contents)).convert("RGB")
        img = img.resize(IMG_SIZE)

        arr = tf.keras.preprocessing.image.img_to_array(img)
        arr = np.expand_dims(arr, axis=0)

        preds = cat_skin_model.predict(arr, verbose=0)[0]

        idx = int(np.argmax(preds))
        disease = cat_idx_to_class.get(idx, "unknown")
        confidence = float(preds[idx] * 100.0)

        advice_map = {
            "Health": "Skin appears healthy.",
            "Flea_Allergy": "Possible flea allergy. Monitor itching and consult a vet.",
            "Ringworm": "Fungal infection detected. Veterinary treatment required.",
            "Scabies": "Highly contagious skin condition. Immediate veterinary care needed.",
        }

        advice = advice_map.get(
            disease, "Consult a veterinarian for proper diagnosis."
        )

        sos_sent = False

        # 🚨 AUTO SOS FOR SERIOUS DISEASES
        if disease in CAT_SOS_DISEASES and confidence >= CAT_SOS_THRESHOLD:
            message = (
                "🚨 *PawSense CAT SKIN SOS ALERT*\n\n"
                f"Condition: *{disease.upper()}*\n"
                f"Confidence: {confidence:.1f}%\n\n"
                "Immediate veterinary attention is recommended."
            )
            try:
                twilio_client.messages.create(
                    from_=WHATSAPP_FROM,
                    to=WHATSAPP_TO,
                    body=message,
                )
                sos_sent = True
                print(f"✅ CAT SOS sent for {disease}")
            except Exception as twilio_err:
                print("❌ Failed to send CAT SOS:", twilio_err)

        return {
            "animal": "cat",
            "disease": disease,
            "confidence": round(confidence, 2),
            "advice": advice,
            "sos_sent": sos_sent,
        }

    except Exception as e:
        return JSONResponse(status_code=500, content={"error": str(e)})

# %%
# !pip install fastapi uvicorn nest_asyncio pillow numpy tensorflow twilio --quiet

# %%
import fastapi
import uvicorn
import nest_asyncio
import PIL
import numpy
import tensorflow
import twilio

print("✅ All packages imported successfully")
# Out:
# ✅ All packages imported successfully
